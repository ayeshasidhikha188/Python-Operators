# %% [markdown]
# # Python Operators
# Operators are used to perform operations on variables and values
# These are standard symbols used for the purpose of logical and arithmetic operations.
# * OPERATORS: These are the special symbols. Eg- + , * , /, etc.
# * OPERAND: It is the value on which the operator is applied
# ### Types of Operators in Python
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparision Operators
# 4. Logical Operators
# 5. bitwise Operators
# 6. Identity Operators
# 7. Membership Operators
# ### Arithmetic Operators in Python
# Python Arithmetic operators are used to perform basic mathematical operations like addition, subtraction, multiplication, and division.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Addition Operator
# In Python, + is the addition operator. It is used to add 2 values.
# ##### Subtraction Operator
# In Python, – is the subtraction operator. It is used to subtract the second value from the first value.
# ##### Multiplication Operator
# In Python, * is the multiplication operator. It is used to find the product of 2 values.
# ##### Division Operator
# In Python, / is the division operator. It is used to find the quotient when the first operand is divided by the second
# ##### Modulus Operator
# In Python, % is the modulus operator. It is used to find the remainder when the first operand is divided by the second.
# ##### Exponentiation Operator
# In Python, ** is the exponentiation operator. It is used to raise the first operand to the power of the second
# ###### Floor Division Operator
# In Python, // is used to conduct the floor division. It is used to find the floor of the quotient when the first operand is divided by the second.

# %%
x,y=15,4
print(x+y) # Addition
print(x-y) # Substraction
print(x*y) # Multiplication
print(x/y) # Division
print(x%y) # Modulus
print(x**y) # Exponential
print(x//y) # Floor division
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %% [markdown]
# ###  Assignment Operators
# Operators are used to perform operations on values and variables. These are the special symbols that carry out arithmetic, logical, bitwise computations. The value the operator operates on is known as Operand.
#  So, Assignment Operators are used to assigning values to variables.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 1. Assign: This operator is used to assign the value of the right side of the expression to the left side operand.

# %%
# Assigning values using  
# Assignment Operator 
a = 3
b = 5
c = a + b 
print(c)
# Out:
# 8

# %% [markdown]
# 2. Add and Assign:
# This operator is used to add the right side operand with the left side operand and then assigning the result to the left operand.

# %%
a = 3
b = 5
  
# a = a + b 
a += b 
  
# Output 
print(a)
# Out:
# 8

# %% [markdown]
# 3. Subtract and Assign:
# This operator is used to subtract the right operand from the left operand and then assigning the result to the left operand

# %%
a = 3
b = 5
# a = a - b 
a -= b  
print(a)
# Out:
# -2

# %% [markdown]
# 4. Multiply and Assign: This operator is used to multiply the right operand with the left operand and then assigning the result to the left operand.

# %%
a = 3
b = 5
# a = a * b 
a *= b 
print(a)
# Out:
# 15

# %% [markdown]
#  5. Divide and Assign: This operator is used to divide the left operand with the right operand and then assigning the result to the left operand.

# %%
a = 3
b = 5
# a = a / b 
a /= b  
print(a)
# Out:
# 0.6

# %% [markdown]
#  6. Modulus and Assign: This operator is used to take the modulus using the left and the right operands and then assigning the result to the left operand.

# %%
a = 3
b = 5
  # a = a % b 
a %= b 
print(a)
# Out:
# 3

# %% [markdown]
# 7. Divide (floor) and Assign: This operator is used to divide the left operand with the right operand and then assigning the result(floor) to the left operand.

# %%
a = 3
b = 5
# a = a // b 
a //= b  
print(a)
# Out:
# 0

# %% [markdown]
# 8. Exponent and Assign: This operator is used to calculate the exponent(raise power) value using operands and then assigning the result to the left operand.

# %%
a = 3
b = 5
# a = a ** b 
a **= b 
print(a)
# Out:
# 243

# %% [markdown]
# ### Comparision Operators
# Comparision operators are used for comparing the values. It either returns True or False according to the condition. These operators are also known as Relation Operators.

# %% [markdown]
# ![compre.jpg](attachment:compre.jpg)

# %% [markdown]
# 1. Greater than: This operator returns True if the left operand is greater than the right operand.
# 2. Less than: This operator returns True if the left operand is less than the right operand.
# 3. Less than or equal to: This operator returns True if the left operand is less than or equal to the right operand.
# 4. Greater than or equal to: This operator returns True if the left operand is greater than or equal to the right operand.
# 5. Equal to: This operator returns True if both the operands are equal i.e. if both the left and the right operand are equal to each other.
# 6. Equal to: This operator returns True if both the operands are equal i.e. if both the left and the right operand are equal to each other.

# %%
x,y=10,15
print(x>y)  #Greaterthan
print(x<y)  #lessthan
print(x>=y) #greaterthan equalto
print(x<=y) #lessthan equal to
print(x==y) #equal to
print(x!=y) #not equal to
# Out:
# False
# True
# False
# True
# False
# True

# %%
'string'=='string'
# Out:
# True

# %% [markdown]
# ### Logical Operators
# In Python, Logical operators are used on conditional statements (either True or False). They perform Logical AND, Logical OR and Logical NOT operations.

# %% [markdown]
# ![logic.jpg](attachment:logic.jpg)

# %% [markdown]
# ##### Logical AND operator
# Logical operator returns True if both the operands are True else it returns False.
# ##### Logical OR operator
# Logical or operator returns True if either of the operands is True
# ##### Logical not operator
# Logical not operator work with the single boolean value. If the boolean value is True it returns False and vice-versa

# %%
x,y,z=True, False, True 
print(x and y,x and z) #logical AND
print(x or y,x or z,y or y) #logical OR
print(not x) #logical not
# Out:
# False True
# True True False
# False

# %% [markdown]
# ### Bitwise Operators
# In Python, bitwise operators are used to perform bitwise calculations on integers. The integers are first converted into binary and then operations are performed on each bit or corresponding pair of bits, hence the name bitwise operators. The result is then returned in decimal format.

# %% [markdown]
# ![bitwise.jpg](attachment:bitwise.jpg)

# %%
x,y=5,6
print(x&y) #bitwise AND
print(x|y) #bitwise OR
print(x^y) #bitwise XOR
print(~x) #bitwise1's complement
print(x<<y) #left-shift
print(x>>y) #Right-shift
# Out:
# 4
# 7
# 3
# -6
# 320
# 0

# %% [markdown]
# ### Identity Operators
# Identity operators in Python are used to compare the memory locations of two objects. The two identity operators are is and is not. The is operator returns True if both objects are the same object in memory, while the is not operator returns True if both objects are not the same object in memory

# %% [markdown]
# ![iden.jpg](attachment:iden.jpg)

# %%
inta, intb=250, 250
lista, listb=[1,2,3], [1,2,3]
listc=lista
print(lista==listb)
print(lista is listb) # is identity
print(lista is not listb) #not is identity
# Out:
# True
# False
# True

# %% [markdown]
# ### Membership Operators
# Python offers two membership operators to check or validate the membership of a value. It tests for membership in a sequence, such as strings, lists, or tuples.
# in operator: The ‘in’ operator is used to check if a character/ substring/ element exists in a sequence or not. Evaluate to True if it finds the specified element in a sequence otherwise False.

# %% [markdown]
# ![mem.jpg](attachment:mem.jpg)

# %%
x,y=[1,27,66], 'Hello'
print(11 in x, 'g' not in y) #in, not in
# Out:
# False True
